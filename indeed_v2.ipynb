# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import string 
from time import sleep
from collections import Counter
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
skill_set = ['r','python','java','c++','ruby','perl','matlab','javascript','scala','excel','tableau',
             'd3js','sas','spss','d3','hadoop','mapreduce','spark',
             'pig','hive','shark','zookeeper','flume','mahout',
             'sql','nosql','hase','cassandra','mongodb','docker','aws']

# %%
def url_split_join(arg):
    '''
    Input: job or city
    Output: text formatted for indeed search 
    '''
    arg = arg.split()
    return '+'.join(word for word in arg)

# %%
#url_split_join('Data Scientist')

# %%
def get_search_url(job,city = None): 
    
    '''
    Input: job and city 
    Output: url that directs to results page for the query 
    '''
    job = url_split_join(job)
    
    if city is None:
        site_list = ['http://www.indeed.com/jobs?q="', job, '"']
    
    else:
        city = url_split_join(city)
        site_list = ['http://www.indeed.com/jobs?q=', job, '&l=', city]
        
    return ''.join(site_list)

# %%
search_url = get_search_url('Data Scientist','Budford','GA')
search_url
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-e26b6d3f2e59> in <module>
# ----> 1 search_url = get_search_url('Data Scientist','Budford','GA')
#       2 search_url
#
# TypeError: get_search_url() takes from 1 to 2 positional arguments but 3 were given

# %%
def get_job_urls(job,city = None,):
    
    '''
    Goes through the result page for the query and return for urls for each organic job posting
    Input: query
    Output: list of all jobs urls features in the query 
    '''
    
    search_url = get_search_url(job,city) #gets results page 
    
    try:
        site = urlopen(search_url).read()
    except:
        return 'Invalid Search' #raises exception if search combination is invalid of if no jobs of that nature exist 
    
    soup = BeautifulSoup(site)
    
    if len(soup) == 0: # in case the default parser lxml doesn't work, try another one
        soup = BeautifulSoup(site, 'html5lib')
    
    
   #gets the total number (organic and sponsored) of job postings
    num_jobs = soup.find(id = 'searchCount').string 
    num_jobs = re.findall('\d+', num_jobs) 
    num_jobs = int("".join(num_jobs[1:]))
    
    #gets the number of page results
    if num_jobs > 10: 
        num_pages = num_jobs//10 
    else: 
        num_pages = 1
    
    page_urls = [] 
    
    #iterates over each page to get the urls within that page
    for i in range(num_pages): 

        start_num = str(i*10)  #page 1 starts at start = 0 , page 1 starts at 10 etc.
        page_url = ''.join([search_url,'&start=', start_num])  
        
        current_page = urlopen(page_url).read()
        page_soup = BeautifulSoup(current_page)
        
        if len(page_soup) == 0: # In case the default parser lxml doesn't work, try another one
            page_soup = BeautifulSoup(page_url, 'html5lib')
        
        results_col =  page_soup.find(id = 'resultsCol')  
        organic_tags = results_col.find_all('div', {'data-tn-component' : "organicJob"}) #gets tags for organic rearch results 
         
        urls  = [x.a.attrs.get('href') for x in organic_tags] #gets the url for the specific job 
        page_urls.append(urls)
        
        if len(urls) < 10: #necessary because sponsored jobs results included in num_jobs
            break 
    
    job_urls = ['https://www.indeed.com'+job for sublist in page_urls for job in sublist]
    
    return job_urls

# %%
job_urls = get_job_urls("Data Scientist", 'Buford','GA')
job_urls[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-730-4c61a2e7c67c> in <module>
# ----> 1 job_urls = get_job_urls("Data Scientist", 'Buford','GA')
#       2 job_urls[1]
#
# TypeError: get_job_urls() takes from 1 to 2 positional arguments but 3 were given

# %%
def get_job_info(job_url):
    
    '''
    Input: url of indeed job posting
    Output: role, title, location and list of words in description
    '''
    
    #TO DO: 1) check that ds3 works 
 
    try:
        site =  urlopen(job_url).read() #opens and returns html
    except:
        return "url could not be opened and read" #CHECK THIS 
    
    soup = BeautifulSoup(site)
    
    if len(soup) == 0: # In case the default parser lxml doesn't work, try another one
        soup = BeautifulSoup(site, 'html5lib')
    
    #general job information
     
    try:
        job_title = soup.find('h3',{'class':"icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title"}).get_text()
    except:
        job_title = 0 
    
    try:
        company_name = soup.find('div',{'class':'icl-u-lg-mr--sm icl-u-xs-mr--xs'}).get_text() #do the other company name thing, do this for state
    except:
        company_name = 0
            
    soup_title = str(soup.title)
    indexes = [i for i, ltr in enumerate(soup_title) if ltr == '-'] #handles if multiple '-' which divide role and location
    
    if len(indexes) == 2: 
        location = soup_title[indexes[0]+1:indexes[1]].split()[:2] 
        city = location[0]
        #state = location [1] 
    
    else: 
        location = soup_title[indexes[-2]+1: indexes[-1]].split()[:2] 
        city = location[0]
        #state = location [1]
    
    #job decription 
    
    content = soup.find('div',{'class':'jobsearch-JobComponent-description icl-u-xs-mt--md'})
    words = content.get_text().split()
    
    punctuation = string.punctuation
    stop_words = stopwords.words('english')
    
    words =[''.join(ch for ch in word if ch not in punctuation) for word in words] #gets rid of punctuation between words to enable joint word adjustment and genereal punctuation 
    words = [re.sub(r"([a-z])([A-Z])", r"\1 \2",word).split() for word in words] #adjusts for joint words
    
    words =[word.lower() for sublist in words for word in sublist] #flattens lists
    job_description = [word for word in words if word not in stop_words and word not in punctuation] #gets rids of stop words

    return job_title, company_name, city,job_description

# %%
job_title, company_name, city,job_description = get_job_info('https://www.indeed.com/rc/clk?jk=a1db79011012cae4&fccid=4c9ec3daa2e076a1&vjs=3')

# %%
#job_title, company_name, city, job_description = get_job_info(query_url)

# %%
#job_title
#company_name
#city
#job_description

# %%
def clean_job_description(job_description,skill_set): 
    '''
    Input: list of words included in job posting 
    Output: 
        Desc = list of stemmed words included in job posting no including tecnical skills 
        skills = technical skills required for job 
    
    '''
    #TO DO      Check whether the skills should be taken out 
    #           The description includes no skills because of the variety of languages can be used to do the same job
    #           Consider whether you want to add back the skills. Because maybe skills are very reflective of nature of job
    
    skills = list(set([word for word in job_description if word in skill_set]))
    text_no_skills = [word for word in job_description if word not in skills]
    
    stemmer = SnowballStemmer('english') #get rid if this if you're going to do semantic similary
    text_no_skills = [stemmer.stem(word) for word in text_no_skills]
    
    return text_no_skills, skills

# %%
text_no_skills, skills = clean_job_description(job_description,skill_set)

# %%
#text_no_skills
#skills

# %%
def get_data(job, skill_set, city = None,):
    '''
    Input:
    Ouput: dataframe with revelant information about job
        Words used for similiarty 
        Skills and location used for filetring results
    '''
    
     #TO DO 1) how do i make this run faster 
    

    job_urls = get_job_urls(job,city) 
    
    if job_urls == 'Invalid Search':
        return 'Invalid Search'
    
    job = []
    unreadable_count = 0 
    
    for url in job_urls:
        job_info = get_job_info(url)
        
        if job_info == "url could not be opened and read":
            unreadable_count += 1
        else:
            job_title, company_name, city,job_description = job_info
            text_no_skills, skills = clean_job_description(job_description,skill_set)
            job.append({'job_title':job_title,"company":company_name,'city':city,'desc': text_no_skills, 'skills':skills,'url': url}) 
        
    return pd.DataFrame(job), unreadable_count

#here that dataframe needs to be with the constraints

# %%
data_scientist_1, count_1 = get_data("Data Scientist", skill_set,'Buford' )

# %%
data_scientist_1
# Out:
#             city                                  company  \
# 0    Alpharetta,                                   Kemper
# 1    Alpharetta,                                     CHEP
# 2       Atlanta,                                 SunTrust
# 3        Duluth,                    National Vision, Inc.
# 4    Alpharetta,                        Change Healthcare
# 5       Atlanta,                                   Arby's
# 6      Norcross,                       Intuitive Surgical
# 7       Suwanee,                        ARRIS Group, Inc.
# 8    Alpharetta,                                  Verizon
# 9       Atlanta,  General Dynamics Information Technology
# 10   Alpharetta,                     Brielle Technologies
# 11   Alpharetta,                               CDK Global
# 12   Alpharetta,                                  Equifax
# 13      Atlanta,                                 SunTrust
# 14   Alpharetta,                                  Siemens
# 15   Alpharetta,                           HI-REZ STUDIOS
# 16         Johns                        SoftVision - TAMS
# 17      Atlanta,                                     KPMG
# 18      Atlanta,                          Cox Enterprises
# 19      Atlanta,                                 SunTrust
# 20   Alpharetta,                                  Equifax
# 21      Atlanta,                       Cox Communications
# 22      Atlanta,  General Dynamics Information Technology
# 23     Norcross,                       Intuitive Surgical
# 24   Alpharetta,                        Change Healthcare
# 25   Alpharetta,                                      ADP
# 26     Norcross,                       Intuitive Surgical
# 27       Duluth,                Tokio Marine Technologies
# 28      Atlanta,                                 SunTrust
# 29      Atlanta,                                     KPMG
# ..           ...                                      ...
# 80      Atlanta,                                     KPMG
# 81   Alpharetta,                                      ADP
# 82      Atlanta,                               Perficient
# 83      Atlanta,                               Perficient
# 84   Alpharetta,                                      ADP
# 85   Alpharetta,                                      ADP
# 86   Alpharetta,                                      ADP
# 87   Alpharetta,                                  Siemens
# 88   Alpharetta,                                      ADP
# 89   Alpharetta,                                      ADP
# 90      Atlanta,                                     KPMG
# 91   Alpharetta,                           Risk Solutions
# 92     Norcross,                       Intuitive Surgical
# 93      Atlanta,                          Cox Enterprises
# 94   Alpharetta,                              Micro Focus
# 95      Atlanta,                          Cox Enterprises
# 96         Sandy              Wakely Consulting Group LLC
# 97      Atlanta,                                     KPMG
# 98      Cumming,                         AutomationDirect
# 99       Duluth,                                Primerica
# 100     Atlanta,                                      CGI
# 101     Atlanta,                          Cox Enterprises
# 102     Atlanta,                                     KPMG
# 103     Atlanta,                                 SunTrust
# 104   Jefferson,                             TRC Staffing
# 105        Sandy              Wakely Consulting Group LLC
# 106     Atlanta,                          Cox Enterprises
# 107  Alpharetta,                              Micro Focus
# 108  Alpharetta,                              BXB Digital
# 109     Atlanta,                       Cox Communications
#
#                                                   desc  \
# 0    [locat, alpharetta, ga, posit, summari, create...
# 1    [parttim, temporari, internship, chep, help, m...
# 2    [perform, sophist, data, analyt, encompass, da...
# 3    [posit, descript, nation, vision, believ, ever...
# 4    [market, analysi, research, industri, topic, i...
# 5    [purpos, posit, posit, critic, understand, dri...
# 6    [internship, job, internship, primari, locat, ...
# 7    [internship, data, analyt, intern, 18003239, d...
# 8    [you'll, you'll, part, team, identifi, trend, ...
# 9    [consult, work, feder, govern, help, develop, ...
# 10   [60, 70, hour, senior, big, data, engin, digit...
# 11   [acceler, career, drive, global, technolog, 2,...
# 12   [job, number, 20765, posit, titl, extern, desc...
# 13   [primarili, respons, develop, calibr, valid, r...
# 14   [divis, process, industri, drive, busi, unit, ...
# 15   [internship, hi, rez, studio, accept, qualifi,...
# 16   [contract, transform, partner, marri, design, ...
# 17   [innov, collabor, shine, lighthous, –, kpmgs, ...
# 18   [cox, communic, look, data, scientist, join, d...
# 19   [posit, statist, quantit, analyst, multipl, op...
# 20   [job, number, 20713, posit, titl, extern, desc...
# 21   [descript, cox, communic, look, data, scientis...
# 22   [consult, work, feder, govern, help, develop, ...
# 23   [job, engin, primari, locat, unit, state, geor...
# 24   [transform, futur, healthcar, isn't, someth, t...
# 25   [unlock, career, potenti, technolog, adp, enjo...
# 26   [internship, job, internship, primari, locat, ...
# 27   [posit, summari, respons, data, engin, develop...
# 28   [corpor, overview, sun, trust, bank, inc, one,...
# 29   [innov, collabor, shine, lighthous, –, kpmgs, ...
# ..                                                 ...
# 80   [known, great, place, work, build, career, kpm...
# 81   [unlock, career, potenti, technolog, adp, enjo...
# 82   [overview, perfici, you'll, deliv, missioncrit...
# 83   [overview, perfici, you'll, deliv, missioncrit...
# 84   [unlock, career, potenti, technolog, adp, enjo...
# 85   [unlock, career, potenti, technolog, adp, enjo...
# 86   [unlock, career, potenti, technolog, adp, enjo...
# 87   [divis, digit, factori, busi, unit, custom, se...
# 88   [adp, hire, princip, applic, develop, full, st...
# 89   [unlock, career, potenti, technolog, adp, enjo...
# 90   [innov, collabor, shine, lighthous, –, kpmgs, ...
# 91   [posit, direct, team, statist, data, model, de...
# 92   [job, engin, primari, locat, unit, state, geor...
# 93   [cox, automot, seek, senior, data, engin, join...
# 94   [micro, focus, everyth, base, simpl, idea, fas...
# 95   [summari, look, talent, peopl, join, team, inc...
# 96   [datadriven, profession, interest, work, marke...
# 97   [innov, collabor, shine, lighthous, –, kpmgs, ...
# 98   [autom, direct, look, senior, developeranalyst...
# 99   [primerica, current, follow, open, corpor, off...
# 100  [sr, data, architect, posit, descript, cgi, hi...
# 101  [role, summari, cox, busi, carrier, sale, supp...
# 102  [known, great, place, work, build, career, kpm...
# 103  [posit, market, analyt, manag, multipl, open, ...
# 104  [trc, profession, solut, seek, bi, busi, analy...
# 105  [datadriven, profession, interest, work, marke...
# 106  [primari, respons, essenti, function, respons,...
# 107  [micro, focus, everyth, base, simpl, idea, fas...
# 108  [bxb, digit, connect, product, convey, platfor...
# 109  [client, analyt, senior, manag, respons, creat...
#
#                                              job_title  \
# 0                            Data Analytics Specialist
# 1                            Internship – Data Science
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                 Data Science Analyst
# 5         Associate Data Scientist, Advanced Analytics
# 6                              Machine Learning Intern
# 7                                Data Analytics Intern
# 8                                       Data Scientist
# 9                                Data Managent Analyst
# 10                  Data Scientists – Machine Learning
# 11           Vehicle Registration Review - Entry level
# 12                  Data Scientist, Keying and Linking
# 13                     Consumer Banking Data Scientist
# 14                     Data Analyst - Machine Learning
# 15                 Machine Learning Engineering Intern
# 16                     Data Scientist (PYTHON, HADOOP)
# 17               Associate, Data Scientist, Healthcare
# 18                                      Data Scientist
# 19                    Statistical Quantitative Analyst
# 20                                      Data Scientist
# 21                                      Data Scientist
# 22                               Data Managent Analyst
# 23                          Machine Learning Scientist
# 24                                        Data Analyst
# 25                                 Lead Data Scientist
# 26                             Machine Learning Intern
# 27                                       Data Engineer
# 28                     Business Banking Data Scientist
# 29                       Sr. Associate, Data Scientist
# ..                                                 ...
# 80                     Manager, Full Stack Development
# 81                 Chief Architect - National Accounts
# 82                                    Mobile Developer
# 83                                    Mobile Architect
# 84                                     DevOps Engineer
# 85                     Senior Business Systems Analyst
# 86                                Salesforce Developer
# 87   Digital Enterprise & Digital Services Segment ...
# 88                     Principal Application Developer
# 89   Principal Application Developer - (Java, Back-...
# 90    Sr. Associate, Data Engineer, Financial Services
# 91                    Director of Statistical Modeling
# 92                                   Software Engineer
# 93                                Senior Data Engineer
# 94                         Software Engineer - Fortify
# 95                 Senior Manager - Advanced Analytics
# 96                                  Consulting Actuary
# 97                Director, Big Data Software Engineer
# 98                            Senior Developer/Analyst
# 99          Information Security Engineering Analyst 2
# 100                                 Sr. Data Architect
# 101  Carrier Sales Support- Data Analyst III- Cox B...
# 102  Senior Associate - Cognitive Data Scientist Na...
# 103                       Marketing Analytical Manager
# 104                                BI Business Analyst
# 105                                 Consulting Actuary
# 106                  Big Data Senior Platform Engineer
# 107       Software Security Research Engineer - AppSec
# 108  BXB Digital: IoT Implementation Manager (Orlan...
# 109                    Client Analytics Senior Manager
#
#                                                 skills  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                 [sql, python, spss, sas, r, tableau]
# 4             [sql, python, hadoop, java, perl, excel]
# 5                                     [sql, python, r]
# 6                                     [matlab, python]
# 7                                             [python]
# 8              [sql, python, hadoop, hive, r, tableau]
# 9                                                   []
# 10   [sql, python, spark, hadoop, java, scala, hive...
# 11                                                  []
# 12                                       [sql, r, sas]
# 13                                        [sql, excel]
# 14    [aws, python, spark, hadoop, java, pig, hive, r]
# 15                                    [sql, python, r]
# 16                            [sql, python, r, hadoop]
# 17                     [aws, python, spark, hadoop, r]
# 18   [sql, python, spark, sas, java, scala, hive, r...
# 19                                    [python, r, sas]
# 20   [sql, python, spark, hadoop, sas, java, scala, r]
# 21   [sql, python, spark, sas, java, scala, hive, r...
# 22                                                  []
# 23                             [sql, python, r, excel]
# 24                         [python, r, tableau, excel]
# 25                       [sql, python, excel, tableau]
# 26                                    [matlab, python]
# 27                               [python, scala, hive]
# 28                          [spark, hive, hadoop, sas]
# 29                     [aws, python, spark, hadoop, r]
# ..                                                 ...
# 80                  [python, spark, sas, hive, pig, r]
# 81   [sql, python, java, zookeeper, javascript, doc...
# 82                                              [java]
# 83                                              [java]
# 84   [sql, python, java, javascript, excel, cassand...
# 85                                             [excel]
# 86                                 [javascript, excel]
# 87                                                  []
# 88                          [java, docker, excel, sql]
# 89                             [java, aws, sql, excel]
# 90   [aws, python, sql, spark, hadoop, perl, hive, ...
# 91                                  [spss, excel, sas]
# 92                          [matlab, python, r, excel]
# 93   [aws, python, spark, hadoop, javascript, java,...
# 94                                   [javascript, sql]
# 95                                    [python, r, sas]
# 96                                             [excel]
# 97     [aws, python, spark, hadoop, java, scala, hive]
# 98                             [java, javascript, sql]
# 99                                               [aws]
# 100                    [aws, sql, spark, hadoop, hive]
# 101                                   [tableau, excel]
# 102                                                 []
# 103                                         [sql, sas]
# 104                                                 []
# 105                                            [excel]
# 106           [aws, python, spark, hadoop, java, perl]
# 107                               [java, python, ruby]
# 108                         [java, python, sql, excel]
# 109                     [aws, python, sql, r, tableau]
#
#                                                    url
# 0    https://www.indeed.com/rc/clk?jk=455afcff50032...
# 1    https://www.indeed.com/rc/clk?jk=dd8f4cf0deba0...
# 2    https://www.indeed.com/rc/clk?jk=b0bf8ea49f266...
# 3    https://www.indeed.com/rc/clk?jk=a1db79011012c...
# 4    https://www.indeed.com/company/Green/jobs/Data...
# 5    https://www.indeed.com/rc/clk?jk=77518cb3e9ed4...
# 6    https://www.indeed.com/rc/clk?jk=ea410ed0881f8...
# 7    https://www.indeed.com/rc/clk?jk=b1f2cf67e21c3...
# 8    https://www.indeed.com/rc/clk?jk=8ab778c265cdf...
# 9    https://www.indeed.com/rc/clk?jk=5f08b1159396c...
# 10   https://www.indeed.com/rc/clk?jk=b5900f9c349e1...
# 11   https://www.indeed.com/rc/clk?jk=76df5879a8760...
# 12   https://www.indeed.com/rc/clk?jk=337a80c92cae2...
# 13   https://www.indeed.com/rc/clk?jk=503e464d73344...
# 14   https://www.indeed.com/rc/clk?jk=6b2c6c59c6049...
# 15   https://www.indeed.com/rc/clk?jk=0bebe755fa377...
# 16   https://www.indeed.com/rc/clk?jk=23db1f6df7fdc...
# 17   https://www.indeed.com/rc/clk?jk=9ebf214102cb9...
# 18   https://www.indeed.com/rc/clk?jk=9c289f099e4f7...
# 19   https://www.indeed.com/rc/clk?jk=ac3d640d3de21...
# 20   https://www.indeed.com/rc/clk?jk=ce8ddc36ef14e...
# 21   https://www.indeed.com/rc/clk?jk=759ba16b59111...
# 22   https://www.indeed.com/rc/clk?jk=5f08b1159396c...
# 23   https://www.indeed.com/rc/clk?jk=a4ad7885c2d9e...
# 24   https://www.indeed.com/rc/clk?jk=2c6de0e905b5e...
# 25   https://www.indeed.com/rc/clk?jk=96eeed3fef8f9...
# 26   https://www.indeed.com/rc/clk?jk=ea410ed0881f8...
# 27   https://www.indeed.com/company/Tokio-Marine-Te...
# 28   https://www.indeed.com/rc/clk?jk=3cbedd41557b5...
# 29   https://www.indeed.com/rc/clk?jk=4eafcca748158...
# ..                                                 ...
# 80   https://www.indeed.com/rc/clk?jk=4c309be1b58a4...
# 81   https://www.indeed.com/rc/clk?jk=b70e30a49be25...
# 82   https://www.indeed.com/rc/clk?jk=48d2e6188d778...
# 83   https://www.indeed.com/rc/clk?jk=6bfc6d1be969c...
# 84   https://www.indeed.com/rc/clk?jk=268ec03edd67a...
# 85   https://www.indeed.com/rc/clk?jk=520608ca81ce0...
# 86   https://www.indeed.com/rc/clk?jk=16cc03c541a3f...
# 87   https://www.indeed.com/rc/clk?jk=2f602ee571962...
# 88   https://www.indeed.com/rc/clk?jk=63c3ab3e6804c...
# 89   https://www.indeed.com/rc/clk?jk=4683fe35a3b2e...
# 90   https://www.indeed.com/rc/clk?jk=8011fbd1b4a1b...
# 91   https://www.indeed.com/rc/clk?jk=242279280b242...
# 92   https://www.indeed.com/rc/clk?jk=cc022a0893cc6...
# 93   https://www.indeed.com/rc/clk?jk=6436bb225ecc7...
# 94   https://www.indeed.com/rc/clk?jk=daa0cd2610e1d...
# 95   https://www.indeed.com/rc/clk?jk=db8948a4f3d1d...
# 96   https://www.indeed.com/rc/clk?jk=c33397c9a8e61...
# 97   https://www.indeed.com/rc/clk?jk=8f15cea1bf1e5...
# 98   https://www.indeed.com/rc/clk?jk=69e9d532b5eb8...
# 99   https://www.indeed.com/rc/clk?jk=3dbdafa864ac9...
# 100  https://www.indeed.com/rc/clk?jk=714455ad75740...
# 101  https://www.indeed.com/rc/clk?jk=476994b166245...
# 102  https://www.indeed.com/rc/clk?jk=8532108f26250...
# 103  https://www.indeed.com/rc/clk?jk=123086ad131e0...
# 104  https://www.indeed.com/rc/clk?jk=7bc46b5a966d6...
# 105  https://www.indeed.com/rc/clk?jk=c33397c9a8e61...
# 106  https://www.indeed.com/rc/clk?jk=c319494d8308c...
# 107  https://www.indeed.com/rc/clk?jk=4122e94bcfb5d...
# 108  https://www.indeed.com/rc/clk?jk=ade678145ae21...
# 109  https://www.indeed.com/rc/clk?jk=8d32377cde062...
#
# [110 rows x 6 columns]

# %%
def dfs_to_csv(path):
    data_scientist, count_1 = get_data("Data Scientist",skill_set)
    data_scientist['job'] = 'data scientist'
    
#     software_developer, count_2 = get_data ("Software Developer",skill_set)
#     software_developer['job'] = 'software developer'
    
#     machine_learning_enginner, count_3 = get_data("Machine Learning Engineer",skill_set)
#     machine_learning_enginner['job'] = 'machine learning enginner'
    
#     full_stack_developer, count_4 = get_data("Full Stack Developer",skill_set)
#     full_stack_developer['job'] = ' full_stack_developer'
    
#     bussiness_intelligence_analyst, count_5 = get_data('Business Intelligence Analyst',skill_set)
#     bussiness_intelligence_analyst['job'] = 'bussiness_intelligence_analyst'
    
#     developer, count_6 = get_data('Developer',skill_set)
#     developer['job'] = 'developer'
    
#     cloud_architect, count_7 = get_data('Cloud Architect',skill_set)
#     cloud_architect['job'] = 'cloud_architect'
    
#     data_engineer, count_8 = get_data("Data Engineer",skill_set)
#     data_engineer['job'] = 'data_engineer'
      
    df.to_csv(path)

# %%
dfs_to_csv(r'/Users/danielatejada 1/Desktop/Galvanize/capstone_project/results_info.csv')

# %%
def get_query_info(query_url,skill_set):
    
    job_title, company_name, city, state, job_description = get_job_info(query_url)
    text_no_skills, skills = clean_job_description(job_description,skill_set)
    
    return job_title, company_name, city, state, text_no_skills, skills

# %%
query_url = get_job_urls('Data Scientist','Boston','MA')[0] #you have to deal with the .string thing

# %%
job_title, company_name, city, state, text_no_skills, skills = get_query_info(query_url,skill_set) #need to fix the title string thing

# %%
def get_top_sim(query_words, df):
    #TO DO 1) here is where I need to incorporate semantic similiarty 
    #      2) can't stem prior to doing similiarty so need to unstem and then resteam
    

    
    query_words = [" ".join(query)]
    job_words = df.desc.apply(lambda x: " ".join(x)).values.tolist() #this gives you a list of list of the jobs 
     
    vectorizer = TfidfVectorizer() #make sure these defaults are correct
    model = vectorizer.fit(job_words)
    
    query_tfidf = model.transform(query_words)
    job_tfidf = model.transform(job_words)
    
    cosine_sim = cosine_similarity(query_tfidf,job_tfidf)
    top_10_sim = cosine_sim.argsort()[0][::-1][0:10]
    
    return cosine_sim, top_10_sim

# %%
cosine_sim, top_10_sim = get_top_sim(text_no_skills,data)

# %%
cosine_sim
top_10_sim
# Out:
# array([20, 22, 24, 13,  6, 23, 14,  8, 26, 18])

# %%
def get_top_jobs(df,indices):
    return df.iloc[indices,:]

# %%
get_top_jobs(data,top_10_sim)
# Out:
#            city             company  \
# 20     Atlanta,             Epsilon
# 22     Roswell,  MotoRad of America
# 24  Alpharetta,                 ADP
# 13     Atlanta,  Cox Communications
# 6   Alpharetta,             Equifax
# 23     Atlanta,  Cox Communications
# 14     Atlanta,  Catalina Marketing
# 8      Atlanta,  Catalina Marketing
# 26  Alpharetta,                 ADP
# 18     Seattle,                KPMG
#
#                                                  desc  \
# 20  [sr, data, scientist, analyt, practic, respons...
# 22  [job, summari, respons, analyz, larg, amount, ...
# 24  [unlock, career, potenti, technolog, adp, enjo...
# 13  [descript, cox, communic, look, data, scientis...
# 6   [job, number, 20765, posit, titl, extern, desc...
# 23  [descript, cox, communic, look, director, data...
# 14  [catalina, catalina, person, digit, media, con...
# 8   [catalina, catalina, person, digit, media, con...
# 26  [adp, hire, princip, applic, develop, full, st...
# 18  [innov, collabor, shine, lighthous, –, kpmgs, ...
#
#                              job_title  \
# 20               Senior Data Scientist
# 22      Insights and Analytics Manager
# 24                Full Stack Developer
# 13                      Data Scientist
# 6   Data Scientist, Keying and Linking
# 23              Director, Data Science
# 14               Senior Data Scientist
# 8                       Data Scientist
# 26     Principal Application Developer
# 18  Sr. Associate, Data Scientist, NLP
#
#                                                skills state  \
# 20  [aws, python, spark, sql, hadoop, sas, java, s...    GA
# 22                                                 []    GA
# 24                              [java, docker, excel]    GA
# 13  [sql, python, spark, sas, java, scala, hive, r...    GA
# 6                                       [sql, r, sas]    GA
# 23  [sql, python, spark, sas, java, scala, hive, r...    GA
# 14                                        [python, r]    GA
# 8                                         [python, r]    GA
# 26                         [java, docker, excel, sql]    GA
# 18                                 [aws, python, sql]    WA
#
#                                                   url
# 20  https://www.indeed.com/rc/clk?jk=18fb5f0e261aa...
# 22  https://www.indeed.com/company/MotoRad-of-Amer...
# 24  https://www.indeed.com/rc/clk?jk=37fafd1237590...
# 13  https://www.indeed.com/rc/clk?jk=759ba16b59111...
# 6   https://www.indeed.com/rc/clk?jk=337a80c92cae2...
# 23  https://www.indeed.com/rc/clk?jk=280ddd1362b17...
# 14  https://www.indeed.com/rc/clk?jk=f7d028a809b84...
# 8   https://www.indeed.com/rc/clk?jk=303a953bd67d7...
# 26  https://www.indeed.com/rc/clk?jk=63c3ab3e6804c...
# 18  https://www.indeed.com/rc/clk?jk=062f6a71626aa...

# %% [markdown]
# # Notes
# - how do you update relevant skills in case a new language comes up?
#     - word associated with data science
#     - essentailly i don't have to feed it in the skills_set
# - which state / city has job posting with the skills that you have
#     - If you're moving from one place to another what skills should you learn
# - On the website track the skills per day, per week, per month so you can see how skills are changing over time
# - Given a certain set of skill, return the job postings that for which you have the highest percentage of those skills
#
#
# ## To Do
# 1. Make sure that it is going through all the pages
# 2. Make sure it is getting all the links on each page
# 3. How do you want to organize
# 4. Are the less jobs in of 84 than actual jobs
# 5. How do you decrease run time
# 6. Can I use this same webscrabing code to go through Udemy, Coursera, Udacity, Ed-Ex and determine which courses are the best?
# 7. Have some sort of counter when the website term

# %%
'http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                   '%2C+', state]
