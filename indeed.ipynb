# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import string 
from time import sleep
from collections import Counter
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
skill_set = ['r','python','java','c++','ruby','perl','matlab','javascript','scala','excel','tableau',
             'd3js','sas','spss','d3','hadoop','mapreduce','spark',
             'pig','hive','shark','zookeeper','flume','mahout',
             'sql','nosql','hase','cassandra','mongodb','docker','aws']

# %%
def url_split_join(arg):
    '''
    Input: job or city
    Output: text formatted for indeed search 
    '''
    arg = arg.split()
    return '+'.join(word for word in arg)

# %%
#url_split_join('Data Scientist')

# %%
def get_search_url(job,city = None, state= None): 
    
    '''
    Input: job and city 
    Output: url that directs to results page for the query 
    '''
    job = url_split_join(job)
    
    if city is None and state is None:
        site_list = ['http://www.indeed.com/jobs?q="', job, '"']
    
    elif city is not None and state is None:
        city = url_split_join(city)
        site_list = ['http://www.indeed.com/jobs?q=', job, '&l=', city]
        
    elif city is None and state is not None:
        state = url_split_join(state)
        site_list = site_list = ['http://www.indeed.com/jobs?q=', job, '&l=', state]
        
    else: 
        city = url_split_join(city)
        state = url_split_join(state)
        site_list = ['http://www.indeed.com/jobs?q=%22', job, '%22&l=', city,
                   '%2C+', state]       
        
    return ''.join(site_list)

# %%
search_url = get_search_url('Machine Learning Engineer','New York', 'NY')
search_url
# Out:
# 'http://www.indeed.com/jobs?q=%22Machine+Learning+Engineer%22&l=New+York%2C+NY'

# %%
def get_job_urls(job,city = None, state = None):
    
    '''
    Goes through the result page for the query and return for urls for each organic job posting
    Input: query
    Output: list of all jobs urls features in the query 
    '''
    
    search_url = get_search_url(job,city, state) #gets results page 
    
    try:
        site = urlopen(search_url).read()
    except:
        return 'Invalid Search' #raises exception if search combination is invalid of if no jobs of that nature exist 
    
    soup = BeautifulSoup(site)
    
    if len(soup) == 0: # in case the default parser lxml doesn't work, try another one
        soup = BeautifulSoup(site, 'html5lib')
    
    
   #gets the total number (organic and sponsored) of job postings
    num_jobs = soup.find(id = 'searchCount').string 
    num_jobs = re.findall('\d+', num_jobs) 
    num_jobs = int("".join(num_jobs[1:]))
    
    #gets the number of page results
    if num_jobs > 10: 
        num_pages = num_jobs//10 
    else: 
        num_pages = 1
    
    page_urls = [] 
    
    #iterates over each page to get the urls within that page
    for i in range(num_pages): 

        start_num = str(i*10)  #page 1 starts at start = 0 , page 1 starts at 10 etc.
        page_url = ''.join([search_url,'&start=', start_num])  
        
        current_page = urlopen(page_url).read()
        page_soup = BeautifulSoup(current_page)
        
        if len(page_soup) == 0: # In case the default parser lxml doesn't work, try another one
            page_soup = BeautifulSoup(page_url, 'html5lib')
        
        results_col =  page_soup.find(id = 'resultsCol')  
        organic_tags = results_col.find_all('div', {'data-tn-component' : "organicJob"}) #gets tags for organic rearch results 
         
        urls  = [x.a.attrs.get('href') for x in organic_tags] #gets the url for the specific job 
        page_urls.append(urls)
        
        if len(urls) < 10: #necessary because sponsored jobs results included in num_jobs
            break 
    
    job_urls = ['https://www.indeed.com'+job for sublist in page_urls for job in sublist]
    
    return job_urls

# %%
job_urls = get_job_urls("Machine Learning Engineer", 'New York','NY')
job_urls[1]
# Out:
# 'https://www.indeed.com/rc/clk?jk=9abe0ba0d21aa953&fccid=c2f64c58662819c7&vjs=3'

# %%
def get_job_info(job_url):
    
    '''
    Input: url of indeed job posting
    Output: role, title, location and list of words in description
    '''
    
    #TO DO: 1) check that ds3 works 
 
    try:
        site =  urlopen(job_url).read() #opens and returns html
    except:
        return "url could not be opened and read" #CHECK THIS 
    
    soup = BeautifulSoup(site)
    
    if len(soup) == 0: # In case the default parser lxml doesn't work, try another one
        soup = BeautifulSoup(site, 'html5lib')
    
    #general job information
     
    try:
        job_title = soup.find('h3',{'class':"icl-u-xs-mb--xs icl-u-xs-mt--none jobsearch-JobInfoHeader-title"}).get_text()
    except:
        job_title = 0 
    
    try:
        company_name = soup.find('div',{'class':'icl-u-lg-mr--sm icl-u-xs-mr--xs'}).get_text() #do the other company name thing, do this for state
    except:
        company_name = 0
                                       
#     soup_title = str(soup.title)
#     indexes = [i for i, ltr in enumerate(soup_title) if ltr == '-'] #handles if multiple '-' which divide role and location
    
#     if len(indexes) == 2: 
#         location = soup_title[indexes[0]+1:indexes[1]].split()[:2] 
#         city = location[0]
        #state = location [1] 
    
#     else: 
#         location = soup_title[indexes[-2]+1: indexes[-1]].split()[:2] 
#         city = location[0]
       #state = location [1]

    try:
        company_info = soup.select('div.jobsearch-InlineCompanyRating.icl-u-xs-mt--xs.jobsearch-DesktopStickyContainer-companyrating')[0].text
        company_info = company_info.split('-')[-1]
        company_info = company_info.split(' ')
    
        info = []
    
        for i in company_info:
            try:
                i = int(i)
                info.append(i)
            except:
                info.append(i)
    
        location = [x for x in info if not isinstance(x, int)]
        city = ' '.join(location[:-1])
        state = location[-1]
    
    except:
        city = 'unavailable'
        state = 'unavailable'
       
    content = soup.find('div',{'class':'jobsearch-JobComponent-description icl-u-xs-mt--md'})
    words = content.get_text().split()
    
    punctuation = string.punctuation
    stop_words = stopwords.words('english')
    
    words =[''.join(ch for ch in word if ch not in punctuation) for word in words] #gets rid of punctuation between words to enable joint word adjustment and genereal punctuation 
    words = [re.sub(r"([a-z])([A-Z])", r"\1 \2",word).split() for word in words] #adjusts for joint words
    
    words =[word.lower() for sublist in words for word in sublist] #flattens lists
    job_description = [word for word in words if word not in stop_words and word not in punctuation] #gets rids of stop words

    return job_title, company_name, city[:-1], state, job_description

# %%
#get_job_info('https://www.indeed.com/rc/clk?jk=9abe0ba0d21aa953&fccid=c2f64c58662819c7&vjs=3')

# %%
#get_job_info('https://www.indeed.com/cmp/Vensiti-Inc.,/jobs/Data-Scientist-7fc1138f244364aa?q=%22Data+Scientist%22&vjs=3')

# %%
#get_job_info('https://www.indeed.com/cmp/Rivel-Research-Group/jobs/Entry-Level-Governance-Esg-Research-Associate-d4cf90c3cff672dd?sjdu=Zzi_VW2ygsY1fzh3Ma9ZsE4zIT1NTXCwgFBhdjeTC3PftXK_q41keFjEJWCY3RMoWfuflRu4OS7wJLBu2LQx-Q&tk=1d0a8l0480ma2003&vjs=3')

# %%
#get_job_info('https://www.indeed.com/viewjob?jk=891cfca2b16bf81e&tk=1d0a2hatg19t8000&from=serp&alid=3&advn=8782415643047922&sjdu=JS6l7gydYCZv8PVkhKxCPnl-QLnRktmQo81JznoYMm1mcmDdYzLAXfklnXERcEVjwletQFW-TwQlaPMsRh6LMg_FF59PQXBkVL66Sl86xFncyvSUuUf5UXvPvCrNA6veXuWVcy8oSAkuEAiehROlopkLfP5Md6JkycvfVYukEoQ')

# %%
def clean_job_description(job_description,skill_set): 
    '''
    Input: list of words included in job posting 
    Output: 
        Desc = list of stemmed words included in job posting no including tecnical skills 
        skills = technical skills required for job 
    
    '''
    #TO DO      Check whether the skills should be taken out 
    #           The description includes no skills because of the variety of languages can be used to do the same job
    #           Consider whether you want to add back the skills. Because maybe skills are very reflective of nature of job
    
    skills = list(set([word for word in job_description if word in skill_set]))
    text_no_skills = [word for word in job_description if word not in skills]
    
    stemmer = SnowballStemmer('english') #get rid if this if you're going to do semantic similary
    text_no_skills = [stemmer.stem(word) for word in text_no_skills]
    
    return text_no_skills, skills

# %%
text_no_skills, skills = clean_job_description(job_description,skill_set)

# %%
#text_no_skills
#skills

# %%
def get_data(job, skill_set, city = None, state = None):
    '''
    Input:
    Ouput: dataframe with revelant information about job
        Words used for similiarty 
        Skills and location used for filetring results
    '''
    
     #TO DO 1) how do i make this run faster 
    

    job_urls = get_job_urls(job,city) 
    
    if job_urls == 'Invalid Search':
        return 'Invalid Search'
    
    job = []
    unreadable_count = 0 
    
    for url in job_urls:
        print(url)
        job_info = get_job_info(url)
        
        if job_info == "url could not be opened and read":
            unreadable_count += 1
        else:
            job_title, company_name, city, state, job_description = job_info
            text_no_skills, skills = clean_job_description(job_description,skill_set)
            job.append({'job_title':job_title,"company":company_name,'city':city, 'state': state,'desc': text_no_skills, 'skills':skills,'url': url}) 
        
    return pd.DataFrame(job), unreadable_count

#here that dataframe needs to be with the constraints

# %%
data_scientist_1, count_1 = get_data("Data Scientist", skill_set,'Buford','GA' )

# %%
data_scientist_1
# Out:
#           city                company  \
# 0   Alpharetta                 Kemper
# 1   Alpharetta                   CHEP
# 2       Duluth  National Vision, Inc.
# 3      Atlanta               SunTrust
# 4   Alpharetta                Verizon
# 5       Duluth               WestRock
# 6   Alpharetta      Change Healthcare
# 7      Atlanta                 Arby's
# 8      Suwanee      ARRIS Group, Inc.
# 9   Alpharetta   Brielle Technologies
# 10  Alpharetta                Equifax
# 11  Alpharetta                Siemens
# 12       Creek      SoftVision - TAMS
# 13  Alpharetta         HI-REZ STUDIOS
# 14     Atlanta               SunTrust
# 15     Atlanta                   KPMG
# 16       Creek      Quasar Analysisis
# 17     Atlanta        Cox Enterprises
# 18     Atlanta     Catalina Marketing
# 19     Atlanta               SunTrust
# 20  Alpharetta                Verizon
# 21     Atlanta                   KPMG
# 22    Norcross     Intuitive Surgical
# 23     Atlanta    Chenega Corporation
# 24    Norcross     Intuitive Surgical
# 25  Alpharetta                    ADP
# 26      Duluth             Tetra Tech
# 27     Atlanta     Cox Communications
# 28       Creek      Quasar Analysisis
# 29     Atlanta               SunTrust
# ..         ...                    ...
# 70     Atlanta                   KPMG
# 71  Alpharetta             LivePerson
# 72     Atlanta        Cox Enterprises
# 73     Atlanta        Cox Enterprises
# 74  Alpharetta               Infinite
# 75    Norcross                 MModal
# 76     Roswell     MotoRad of America
# 77  Alpharetta                   TSYS
# 78     Atlanta               SunTrust
# 79     Atlanta                 Arby's
# 80  Alpharetta                    ADP
# 81  Alpharetta                    ADP
# 82     Atlanta             Perficient
# 83  Alpharetta                Siemens
# 84  Alpharetta                    ADP
# 85  Alpharetta                    ADP
# 86  Alpharetta                    ADP
# 87  Alpharetta                    ADP
# 88     Atlanta             Perficient
# 89  Alpharetta                    ADP
# 90    Norcross          Iron Mountain
# 91     Atlanta     Catalina Marketing
# 92     Atlanta               SunTrust
# 93     Atlanta        Cox Enterprises
# 94     Atlanta                    CGI
# 95     Cumming       AutomationDirect
# 96     Roswell               Tredence
# 97     Atlanta        Cox Enterprises
# 98      Duluth              Primerica
# 99      Duluth               WestRock
#
#                                                  desc  \
# 0   [locat, alpharetta, ga, posit, summari, create...
# 1   [parttim, temporari, internship, chep, help, m...
# 2   [posit, descript, nation, vision, believ, ever...
# 3   [perform, sophist, data, analyt, encompass, da...
# 4   [you'll, you'll, part, team, identifi, trend, ...
# 5   [nyse, wrk, partner, custom, provid, different...
# 6   [market, analysi, research, industri, topic, i...
# 7   [purpos, posit, posit, critic, understand, dri...
# 8   [internship, data, analyt, intern, 18003239, d...
# 9   [60, 70, hour, senior, big, data, engin, digit...
# 10  [job, number, 20765, posit, titl, extern, desc...
# 11  [divis, process, industri, drive, busi, unit, ...
# 12  [contract, transform, partner, marri, design, ...
# 13  [internship, hi, rez, studio, accept, qualifi,...
# 14  [primarili, respons, develop, calibr, valid, r...
# 15  [innov, collabor, shine, lighthous, –, kpmgs, ...
# 16  [quasar, analysi, custom, research, seek, cand...
# 17  [cox, communic, look, data, scientist, join, d...
# 18  [catalina, catalina, person, digit, media, con...
# 19  [posit, statist, quantit, analyst, multipl, op...
# 20  [you'll, use, digit, data, fuel, propel, us, b...
# 21  [innov, collabor, shine, lighthous, –, kpmgs, ...
# 22  [internship, job, internship, primari, locat, ...
# 23  [chenega, profession, technic, servic, llc, se...
# 24  [job, engin, primari, locat, unit, state, geor...
# 25  [unlock, career, potenti, technolog, adp, enjo...
# 26  [environment, scientist, engin, jr, level, 103...
# 27  [descript, cox, communic, look, data, scientis...
# 28  [quasar, analysi, custom, research, seek, cand...
# 29  [corpor, overview, sun, trust, bank, inc, one,...
# ..                                                ...
# 70  [known, great, place, work, build, career, kpm...
# 71  [today, consum, expect, mobil, access, everyth...
# 72  [cox, communic, analyt, center, excel, co, e, ...
# 73  [cox, communic, look, director, data, scienc, ...
# 74  [contract, job, summari, big, data, develop, l...
# 75  [posit, summari, posit, requir, perform, duti,...
# 76  [job, summari, respons, analyz, larg, amount, ...
# 77  [machin, learn, engin, digit, innov, team, tsy...
# 78  [posit, market, analyt, manag, multipl, open, ...
# 79  [purpos, posit, purpos, posit, use, analyt, da...
# 80  [unlock, career, potenti, technolog, adp, enjo...
# 81  [unlock, career, potenti, technolog, adp, enjo...
# 82  [overview, perfici, you'll, deliv, missioncrit...
# 83  [divis, digit, factori, busi, unit, custom, se...
# 84  [unlock, career, potenti, technolog, adp, enjo...
# 85  [adp, hire, princip, applic, develop, full, st...
# 86  [unlock, career, potenti, technolog, adp, enjo...
# 87  [unlock, career, potenti, technolog, adp, enjo...
# 88  [overview, perfici, you'll, deliv, missioncrit...
# 89  [unlock, career, potenti, technolog, adp, enjo...
# 90  [overview, found, 1951, iron, mountain, incorp...
# 91  [catalina, catalina, person, digit, media, con...
# 92  [sun, trust, audit, servic, integr, activ, par...
# 93  [job, descript, lead, architectur, data, servi...
# 94  [sr, data, architect, posit, descript, cgi, hi...
# 95  [autom, direct, look, senior, developeranalyst...
# 96  [develop, expert, knowledg, client, busi, prob...
# 97  [summari, look, talent, peopl, join, team, inc...
# 98  [primerica, current, follow, open, corpor, off...
# 99  [nyse, wrk, partner, custom, provid, different...
#
#                                             job_title  \
# 0                           Data Analytics Specialist
# 1                           Internship – Data Science
# 2                                      Data Scientist
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5                            Associate Data Scientist
# 6                                Data Science Analyst
# 7        Associate Data Scientist, Advanced Analytics
# 8                               Data Analytics Intern
# 9                  Data Scientists – Machine Learning
# 10                 Data Scientist, Keying and Linking
# 11                    Data Analyst - Machine Learning
# 12                    Data Scientist (PYTHON, HADOOP)
# 13                Machine Learning Engineering Intern
# 14                    Consumer Banking Data Scientist
# 15              Associate, Data Scientist, Healthcare
# 16            Analyst–Quasar Analysis Custom Research
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19                   Statistical Quantitative Analyst
# 20                              Senior Data Scientist
# 21              Associate, Data Scientist, Healthcare
# 22                            Machine Learning Intern
# 23                          Health Scientist III-CPTS
# 24                         Machine Learning Scientist
# 25                                Lead Data Scientist
# 26    Environmental Scientist or Engineer (Jr. Level)
# 27                                     Data Scientist
# 28            Analyst–Quasar Analysis Custom Research
# 29                    Business Banking Data Scientist
# ..                                                ...
# 70                     Senior Associate, Data Science
# 71                                       Data Analyst
# 72                                   Data Engineer II
# 73                             Director, Data Science
# 74                          Big Data/Hadoop Developer
# 75                       Business Data Analyst - Lead
# 76                     Insights and Analytics Manager
# 77  Machine Learning Engineer, Digital Innovation ...
# 78                       Marketing Analytical Manager
# 79                   Sr. Analyst of Loyalty Analytics
# 80                Chief Architect - National Accounts
# 81                    Senior Business Systems Analyst
# 82                                   Mobile Architect
# 83  Digital Enterprise & Digital Services Segment ...
# 84                                    DevOps Engineer
# 85                    Principal Application Developer
# 86                         Lead Application Developer
# 87                                   Lead QA Engineer
# 88                            Senior Mobile Developer
# 89  Senior QA Quality Assurance Engineer - (Automa...
# 90  Senior Technical Program Manager - Data & Anal...
# 91                        Director, Digital Analytics
# 92                            IT Audit Manager - Data
# 93                                Lead Data Architect
# 94                                 Sr. Data Architect
# 95                           Senior Developer/Analyst
# 96                             Data Architect – Cloud
# 97                Senior Manager - Advanced Analytics
# 98         Information Security Engineering Analyst 2
# 99                IT Manager - Data/Cloud Engineering
#
#                                                skills state  \
# 0                                                  []    GA
# 1                                                  []    GA
# 2                [spss, r, tableau, sas, python, sql]    GA
# 3                                                  []    GA
# 4             [r, tableau, hadoop, python, hive, sql]    GA
# 5              [spark, java, r, hadoop, spss, python]    GA
# 6            [perl, excel, java, hadoop, python, sql]    GA
# 7                                    [r, sql, python]    GA
# 8                                            [python]    GA
# 9   [spark, java, r, tableau, hadoop, d3js, scala,...    GA
# 10                                      [r, sql, sas]    GA
# 11   [aws, spark, java, r, hadoop, pig, python, hive]    GA
# 12                           [hadoop, r, sql, python]    GA
# 13                                   [r, sql, python]    GA
# 14                                       [sql, excel]    GA
# 15                    [aws, spark, r, hadoop, python]    GA
# 16                                                 []    GA
# 17  [sas, spark, r, java, tableau, scala, python, ...    GA
# 18                                        [r, python]    GA
# 19                                   [r, python, sas]    GA
# 20  [aws, spark, java, tableau, scala, python, hiv...    GA
# 21                    [aws, spark, r, hadoop, python]    GA
# 22                                   [python, matlab]    GA
# 23                                                 []    GA
# 24                            [sql, r, excel, python]    GA
# 25                      [tableau, excel, sql, python]    GA
# 26                                                 []    GA
# 27  [sas, spark, r, java, tableau, scala, python, ...    GA
# 28                                                 []    GA
# 29                         [spark, hadoop, hive, sas]    GA
# ..                                                ...   ...
# 70                               [spark, aws, mahout]    GA
# 71  [r, tableau, hadoop, javascript, python, hive,...    GA
# 72  [sas, spark, r, java, docker, tableau, hadoop,...    GA
# 73  [sas, spark, r, java, tableau, scala, python, ...    GA
# 74  [spark, java, r, tableau, hadoop, d3js, python...    GA
# 75                             [tableau, sql, python]    GA
# 76                                                 []    GA
# 77                                [java, sql, python]    GA
# 78                                         [sql, sas]    GA
# 79                                   [r, sql, python]    GA
# 80  [ruby, zookeeper, excel, java, docker, python,...    GA
# 81                                            [excel]    GA
# 82                                             [java]    GA
# 83                                                 []    GA
# 84  [ruby, excel, java, python, javascript, sql, c...    GA
# 85                         [excel, docker, java, sql]    GA
# 86                                 [excel, java, sql]    GA
# 87                                 [excel, java, sql]    GA
# 88                                             [java]    GA
# 89                         [excel, java, sql, python]    GA
# 90                                      [hadoop, sql]    GA
# 91                [sas, r, hadoop, python, hive, sql]    GA
# 92     [python, spark, r, tableau, hadoop, sas, hive]    GA
# 93                   [spark, java, python, hive, sql]    GA
# 94                    [aws, spark, hadoop, hive, sql]    GA
# 95                            [java, javascript, sql]    GA
# 96                 [aws, spark, java, hadoop, python]    GA
# 97                                   [r, python, sas]    GA
# 98                                              [aws]    GA
# 99  [aws, spark, java, tableau, hadoop, pig, scala...    GA
#
#                                                   url
# 0   https://www.indeed.com/rc/clk?jk=455afcff50032...
# 1   https://www.indeed.com/rc/clk?jk=dd8f4cf0deba0...
# 2   https://www.indeed.com/rc/clk?jk=a1db79011012c...
# 3   https://www.indeed.com/rc/clk?jk=b0bf8ea49f266...
# 4   https://www.indeed.com/rc/clk?jk=8ab778c265cdf...
# 5   https://www.indeed.com/rc/clk?jk=b8db29caa083b...
# 6   https://www.indeed.com/company/Green/jobs/Data...
# 7   https://www.indeed.com/rc/clk?jk=77518cb3e9ed4...
# 8   https://www.indeed.com/rc/clk?jk=b1f2cf67e21c3...
# 9   https://www.indeed.com/rc/clk?jk=b5900f9c349e1...
# 10  https://www.indeed.com/rc/clk?jk=337a80c92cae2...
# 11  https://www.indeed.com/rc/clk?jk=6b2c6c59c6049...
# 12  https://www.indeed.com/rc/clk?jk=23db1f6df7fdc...
# 13  https://www.indeed.com/rc/clk?jk=0bebe755fa377...
# 14  https://www.indeed.com/rc/clk?jk=503e464d73344...
    job_df, count = get_data(job,skill_set)
    job_df['job'] = job
    job_df.to_csv(path + file_name + '.csv')
    
    return count 
    
#     software_developer, count_2 = get_data ("Software Developer",skill_set)
#     software_developer['job'] = 'software developer'
    
#     machine_learning_enginner, count_3 = get_data("Machine Learning Engineer",skill_set)
#     machine_learning_enginner['job'] = 'machine learning enginner'
    
#     full_stack_developer, count_4 = get_data("Full Stack Developer",skill_set)
#     full_stack_developer['job'] = ' full_stack_developer'
    
#     bussiness_intelligence_analyst, count_5 = get_data('Business Intelligence Analyst',skill_set)
#     bussiness_intelligence_analyst['job'] = 'bussiness_intelligence_analyst'
    
#     developer, count_6 = get_data('Developer',skill_set)
#     developer['job'] = 'developer'
    
#     cloud_architect, count_7 = get_data('Cloud Architect',skill_set)
#     cloud_architect['job'] = 'cloud_architect'
    
#     data_engineer, count_8 = get_data("Data Engineer",skill_set)
#     data_engineer['job'] = 'data_engineer'
      
#   df.to_csv(path)

# %%
ds_count = dfs_to_csv('Data Scientist','data_scientist',skill_set,r'/Users/danielatejada 1/Desktop/Galvanize/capstone_project/')

# %%
ds_count
# Out:
# 1

# %%
#l = []
#l[-1]

# %%
mle_count = dfs_to_csv('Machine Learning Engineer', 'machine_learning_engineer',skill_set, r'/Users/danielatejada 1/Desktop/Galvanize/capstone_project/' )
# Out:
# https://www.indeed.com/rc/clk?jk=2d26a1c7d41216e5&fccid=c46d0116f6e69eae&vjs=3
# https://www.indeed.com/rc/clk?jk=9abe0ba0d21aa953&fccid=c2f64c58662819c7&vjs=3
# https://www.indeed.com/company/Lennon-Wright-Associates/jobs/Machine-Learning-Engineer-a842ac20cfad9549?fccid=614380d09db22ef8&vjs=3
# https://www.indeed.com/rc/clk?jk=e11a7cdffd72e8c6&fccid=fe404d18bb9eef1e&vjs=3
# https://www.indeed.com/rc/clk?jk=dd8b1c8d9a2e9bd8&fccid=0bfd6b75d98e7714&vjs=3
# https://www.indeed.com/rc/clk?jk=086ccddb3af0e8e0&fccid=bc1c9d9d782c6b91&vjs=3
# https://www.indeed.com/rc/clk?jk=87f462d8f1109af8&fccid=046813bd6f2871bb&vjs=3
# https://www.indeed.com/company/Marccx-Media/jobs/Machine-Learning-Engineer-b4b45f7c9d6a54ad?fccid=e2478ef00fceff18&vjs=3
# https://www.indeed.com/rc/clk?jk=1a9c4e5ad5cb4393&fccid=ce3b6f8ba0332e43&vjs=3
# https://www.indeed.com/rc/clk?jk=f3e86f3dcede1080&fccid=b2f280610e37d354&vjs=3
# https://www.indeed.com/rc/clk?jk=9215ba4af59ce075&fccid=913e1b259c8d65e2&vjs=3
# https://www.indeed.com/rc/clk?jk=086ccddb3af0e8e0&fccid=bc1c9d9d782c6b91&vjs=3
# https://www.indeed.com/rc/clk?jk=b7a01ccb470daca3&fccid=09abad886b83c501&vjs=3
# https://www.indeed.com/company/Emogi-Technologies/jobs/Data-Scientist-Machine-Learning-Engineer-aebee4bd39cd75dc?fccid=20eda1d7f5120d0a&vjs=3
# https://www.indeed.com/rc/clk?jk=f1db6cabcd983e69&fccid=6ca88ff46e4be5b7&vjs=3
# https://www.indeed.com/rc/clk?jk=d1f00e1f5770e16f&fccid=913e1b259c8d65e2&vjs=3
# https://www.indeed.com/rc/clk?jk=4d4d005cade7d3c6&fccid=2953cfd7217114d1&vjs=3
# https://www.indeed.com/rc/clk?jk=6c74f5c2a0c11002&fccid=83f65cb2793f3af5&vjs=3
# https://www.indeed.com/rc/clk?jk=b3a41ab77d92cb8b&fccid=fc652b40dd1ba2a0&vjs=3
# https://www.indeed.com/rc/clk?jk=03342478c19ed1e9&fccid=a1b622cd76ce185e&vjs=3
# https://www.indeed.com/rc/clk?jk=655618e1b768655b&fccid=7f90bc77737eeea4&vjs=3
# https://www.indeed.com/rc/clk?jk=d1f00e1f5770e16f&fccid=913e1b259c8d65e2&vjs=3
# https://www.indeed.com/company/Suited/jobs/Machine-Learning-Engineer-e1c23dad50a7b3d8?fccid=47b15b773b046d14&vjs=3
# https://www.indeed.com/rc/clk?jk=b85564ddbd3840eb&fccid=1d7146bd38091a7a&vjs=3
# https://www.indeed.com/rc/clk?jk=95adef10cb8d9424&fccid=fe404d18bb9eef1e&vjs=3
# https://www.indeed.com/rc/clk?jk=8d534d4e51e2058a&fccid=89ea8c26aa776a95&vjs=3
# https://www.indeed.com/rc/clk?jk=763e9ae7cb7e0769&fccid=a7081d2f52016a53&vjs=3
# https://www.indeed.com/company/Volvo-Cars-R-&-D-Silicon-Valley-Center/jobs/Ai-Machine-Learning-Engineer-2cbddffee1c9b827?fccid=a2e91b4a0cb3b8d7&vjs=3
# https://www.indeed.com/company/Passage-AI/jobs/Machine-Learning-Engineer-8e7459c541b134d7?fccid=173b1ad12e4cc66a&vjs=3
# https://www.indeed.com/rc/clk?jk=460159a790d57fb3&fccid=3ef6655314901dcd&vjs=3
# https://www.indeed.com/rc/clk?jk=b91de3c7b129ae15&fccid=510aa29fcf8f87d9&vjs=3
# https://www.indeed.com/rc/clk?jk=d738db7b8e8570ac&fccid=16f2f62ada6bc920&vjs=3

# %%
#soft_eng_count = dfs_to_csv('Software Developer', 'softwate_developer',skill_set,r'/Users/danielatejada 1/Desktop/Galvanize/capstone_project/')

# %%
query_url = get_job_urls('Data Scientist','Boston','MA')[0] #you have to deal with the .string thing

# %%
job_title, company_name, city, state, text_no_skills, skills = get_query_info(query_url,skill_set) #need to fix the title string thing

# %%
def get_top_sim(query_words, df):
    #TO DO 1) here is where I need to incorporate semantic similiarty 
    #      2) can't stem prior to doing similiarty so need to unstem and then resteam
    

    
    query_words = [" ".join(query)]
    job_words = df.desc.apply(lambda x: " ".join(x)).values.tolist() #this gives you a list of list of the jobs 
     
    vectorizer = TfidfVectorizer() #make sure these defaults are correct
    model = vectorizer.fit(job_words)
    
    query_tfidf = model.transform(query_words)
    job_tfidf = model.transform(job_words)
    
    cosine_sim = cosine_similarity(query_tfidf,job_tfidf)
    top_10_sim = cosine_sim.argsort()[0][::-1][0:10]
    
    return cosine_sim, top_10_sim

# %%
cosine_sim, top_10_sim = get_top_sim(text_no_skills,data)

# %%
cosine_sim
top_10_sim
# Out:
# array([20, 22, 24, 13,  6, 23, 14,  8, 26, 18])

# %%
def get_top_jobs(df,indices):
    return df.iloc[indices,:]

# %%
get_top_jobs(data,top_10_sim)
# Out:
#            city             company  \
# 20     Atlanta,             Epsilon
# 22     Roswell,  MotoRad of America
# 24  Alpharetta,                 ADP
# 13     Atlanta,  Cox Communications
# 6   Alpharetta,             Equifax
# 23     Atlanta,  Cox Communications
# 14     Atlanta,  Catalina Marketing
# 8      Atlanta,  Catalina Marketing
# 26  Alpharetta,                 ADP
# 18     Seattle,                KPMG
#
#                                                  desc  \
# 20  [sr, data, scientist, analyt, practic, respons...
# 22  [job, summari, respons, analyz, larg, amount, ...
# 24  [unlock, career, potenti, technolog, adp, enjo...
# 13  [descript, cox, communic, look, data, scientis...
# 6   [job, number, 20765, posit, titl, extern, desc...
# 23  [descript, cox, communic, look, director, data...
# 14  [catalina, catalina, person, digit, media, con...
# 8   [catalina, catalina, person, digit, media, con...
# 26  [adp, hire, princip, applic, develop, full, st...
# 18  [innov, collabor, shine, lighthous, –, kpmgs, ...
#
#                              job_title  \
# 20               Senior Data Scientist
# 22      Insights and Analytics Manager
# 24                Full Stack Developer
# 13                      Data Scientist
# 6   Data Scientist, Keying and Linking
# 23              Director, Data Science
# 14               Senior Data Scientist
# 8                       Data Scientist
# 26     Principal Application Developer
# 18  Sr. Associate, Data Scientist, NLP
#
#                                                skills state  \
# 20  [aws, python, spark, sql, hadoop, sas, java, s...    GA
# 22                                                 []    GA
# 24                              [java, docker, excel]    GA
# 13  [sql, python, spark, sas, java, scala, hive, r...    GA
# 6                                       [sql, r, sas]    GA
# 23  [sql, python, spark, sas, java, scala, hive, r...    GA
# 14                                        [python, r]    GA
# 8                                         [python, r]    GA
# 26                         [java, docker, excel, sql]    GA
# 18                                 [aws, python, sql]    WA
#
#                                                   url
# 20  https://www.indeed.com/rc/clk?jk=18fb5f0e261aa...
# 22  https://www.indeed.com/company/MotoRad-of-Amer...
# 24  https://www.indeed.com/rc/clk?jk=37fafd1237590...
# 13  https://www.indeed.com/rc/clk?jk=759ba16b59111...
# 6   https://www.indeed.com/rc/clk?jk=337a80c92cae2...
# 23  https://www.indeed.com/rc/clk?jk=280ddd1362b17...
# 14  https://www.indeed.com/rc/clk?jk=f7d028a809b84...
# 8   https://www.indeed.com/rc/clk?jk=303a953bd67d7...
# 26  https://www.indeed.com/rc/clk?jk=63c3ab3e6804c...
# 18  https://www.indeed.com/rc/clk?jk=062f6a71626aa...

# %% [markdown]
# # Notes
# - how do you update relevant skills in case a new language comes up?
#     - word associated with data science
#     - essentailly i don't have to feed it in the skills_set
# - which state / city has job posting with the skills that you have
#     - If you're moving from one place to another what skills should you learn
# - On the website track the skills per day, per week, per month so you can see how skills are changing over time
# - Given a certain set of skill, return the job postings that for which you have the highest percentage of those skills
#
#
# ## To Do
# 1. Make sure that it is going through all the pages
# 2. Make sure it is getting all the links on each page
# 3. How do you want to organize
# 4. Are the less jobs in of 84 than actual jobs
# 5. How do you decrease run time
# 6. Can I use this same webscrabing code to go through Udemy, Coursera, Udacity, Ed-Ex and determine which courses are the best?
# 7. Have some sort of counter when the website term

# %%
'http://www.indeed.com/jobs?q=%22', final_job, '%22&l=', final_city,
                   '%2C+', state]
